# %%
from dataclasses import dataclass
from typing import Tuple, Dict, Mapping, Tuple
from rl.dynamic_programming import policy_iteration_result
from rl.markov_decision_process import FiniteMarkovDecisionProcess
from rl.policy import FiniteDeterministicPolicy
from rl.markov_process import FiniteMarkovProcess, FiniteMarkovRewardProcess
from rl.distribution import Categorical
from scipy.stats import poisson

# %%
@dataclass(frozen=True)
class InventoryState:
    on_hand_1: int
    on_order_1: int

    on_hand_2: int
    on_order_2: int

    def inventory_position(self) -> Tuple[int, int]:
        return (self.on_hand_1 + self.on_order_1, self.on_hand_2 + self.on_order_2)

    def ip1(self) -> int:
        return self.on_hand_1 + self.on_order_1

    def ip2(self) -> int:
        return self.on_hand_2 + self.on_order_2


InvOrderMapping = Mapping[
    InventoryState, Mapping[int, Categorical[Tuple[InventoryState, float]]]
]


class DoubleInventoryMDPCap(FiniteMarkovDecisionProcess[InventoryState, int]):
    def __init__(
        self,
        capacities: Tuple[int, int],
        poisson_lambdas: Tuple[float, float],
        holding_costs: Tuple[float, float],
        stockout_costs: Tuple[float, float],
        order_cost: float,
        transfer_cost: float,
    ):
        self.capacities: Tuple[int, int] = capacities
        self.holding_costs: Tuple[float, float] = holding_costs
        self.stockout_costs: Tuple[float, float] = stockout_costs
        self.order_cost: float = order_cost
        self.transfer_cost: float = transfer_cost

        self.poisson_lambdas = poisson_lambdas
        self.poisson_distr_1 = poisson(self.poisson_lambdas[0])
        self.poisson_distr_2 = poisson(self.poisson_lambdas[1])
        super().__init__(self.get_action_transition_reward_map())

    def get_action_transition_reward_map(self) -> InvOrderMapping:
        d: Dict[
            InventoryState,
            Dict[Tuple[int, int], Categorical[Tuple[InventoryState, float]]],
        ] = {}

        for alpha1 in range(self.capacities[0] + 1):
            for beta1 in range(self.capacities[0] + 1 - alpha1):
                for alpha2 in range(self.capacities[1] + 1):
                    for beta2 in range(self.capacities[1] - alpha2):
                        state: InventoryState = InventoryState(
                            alpha1, beta1, alpha2, beta2
                        )

                        ip: Tuple[int, int] = state.inventory_position()

                        base_reward: float = (
                            -self.holding_costs[0] * alpha1
                            - self.holding_costs[1] * alpha2
                        )
                        # will be held overnight
                        d1: Dict[
                            Tuple[int, int], Categorical[Tuple[InventoryState, float]]
                        ] = {}

                        # transfer refers to the amount transferred from the perspective of shop 1
                        for transfer in range(-alpha1, alpha2 + 1):

                            for order1 in range(
                                self.capacities[0]
                                - state.inventory_position()[0]
                                - transfer
                                + 1
                            ):
                                for order2 in range(
                                    self.capacities[1]
                                    - state.inventory_position()[1]
                                    + transfer
                                    + 1
                                ):
                                    running_reward = (
                                        base_reward
                                        - transfer_cost * (transfer != 0)
                                        - order_cost * (order1 != 0 + order2 != 0)
                                    )

                                    sr_probs_dict: Dict[
                                        Tuple[InventoryState, float], float
                                    ] = {
                                        (
                                            InventoryState(
                                                ip[0] + transfer - i,
                                                order1,
                                                ip[1] - transfer - j,
                                                order2,
                                            ),
                                            running_reward,
                                        ): self.poisson_distr_1.pmf(i)
                                        * self.poisson_distr_2.pmf(j)
                                        for i in range(ip[0] - transfer)
                                        for j in range(ip[1] + transfer)
                                    }

                                    #### Covering cases of stockout ####
                                    stockout_prob_1: float = (
                                        1
                                        - self.poisson_distr_1.cdf(ip[0] - transfer - 1)
                                    )
                                    stockout_prob_2: float = (
                                        1
                                        - self.poisson_distr_2.cdf(ip[1] + transfer - 1)
                                    )
                                    expected_stockout_cost_1 = self.stockout_costs[
                                        0
                                    ] * (
                                        stockout_prob_1
                                        * (self.poisson_lambdas[0] - ip[0])
                                        + ip[0] * self.poisson_distr_1.pmf(ip[0])
                                    )

                                    expected_stockout_cost_2 = self.stockout_costs[
                                        1
                                    ] * (
                                        stockout_prob_2
                                        * (self.poisson_lambdas[1] - ip[1])
                                        + ip[1] * self.poisson_distr_1.pmf(ip[1])
                                    )

                                    #### First stockout but not the second ####
                                    sr_probs_dict.update(
                                        {
                                            (
                                                InventoryState(
                                                    0,
                                                    order1,
                                                    ip[1] - transfer - j,
                                                    order2,
                                                ),
                                                running_reward
                                                - expected_stockout_cost_1,
                                            ): stockout_prob_1
                                            * self.poisson_distr_2.pmf(j)
                                            for j in range(ip[1] - transfer)
                                        }
                                    )

                                    #### Second stockout but not the first ####
                                    sr_probs_dict.update(
                                        {
                                            (
                                                InventoryState(
                                                    ip[0] + transfer - i,
                                                    order1,
                                                    0,
                                                    order2,
                                                ),
                                                running_reward
                                                - expected_stockout_cost_2,
                                            ): stockout_prob_2
                                            * self.poisson_distr_1.pmf(i)
                                            for i in range(ip[0] + transfer)
                                        }
                                    )

                                    #### Both stock out ####

                                    sr_probs_dict[
                                        InventoryState(0, order1, 0, order2),
                                        running_reward
                                        - expected_stockout_cost_1
                                        - expected_stockout_cost_2,
                                    ] = (
                                        stockout_prob_1 * stockout_prob_2
                                    )

                                    d1[(order1, order2, transfer)] = Categorical(
                                        sr_probs_dict
                                    )
                        d[state] = d1
            return d

# %%
capacities = (7, 10)
poisson_lambdas = (3, 1.5)
holding_costs = (2.0, 1.0)
stockout_costs = (10.0, 7.5)
order_cost = 4.0
transfer_cost = 1.0

di_mdp: FiniteMarkovDecisionProcess[InventoryState, int] = DoubleInventoryMDPCap(
    capacities=capacities,
    poisson_lambdas=poisson_lambdas,
    holding_costs=holding_costs,
    stockout_costs=stockout_costs,
    order_cost=order_cost,
    transfer_cost=transfer_cost
)

# %%
policy_iteration_result(mdp=di_mdp, gamma=0.9)
# Out:
# ({NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=0, on_order_2=0)): -42.066730125012384,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=0, on_order_2=1)): -34.165572948084204,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=0, on_order_2=2)): -32.34076286173448,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=0, on_order_2=3)): -32.10159806366085,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=0, on_order_2=4)): -33.19618791865703,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=0, on_order_2=5)): -34.78772859479463,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=0, on_order_2=6)): -35.22600411650624,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=0, on_order_2=7)): -35.918955402225066,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=0, on_order_2=8)): -36.7396821390842,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=0, on_order_2=9)): -37.654640919609726,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=1, on_order_2=0)): -35.03000418782921,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=1, on_order_2=1)): -33.34076286173448,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=1, on_order_2=2)): -33.101598063660845,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=1, on_order_2=3)): -34.19618791865703,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=1, on_order_2=4)): -35.03397631263295,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=1, on_order_2=5)): -36.22600411650624,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=1, on_order_2=6)): -36.918955402225066,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=1, on_order_2=7)): -37.73968213908421,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=1, on_order_2=8)): -38.65464091960973,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=2, on_order_2=0)): -33.61001628282134,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=2, on_order_2=1)): -34.10159806366085,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=2, on_order_2=2)): -35.196187918657024,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=2, on_order_2=3)): -36.03397631263295,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=2, on_order_2=4)): -37.22600411650624,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=2, on_order_2=5)): -37.830637518445194,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=2, on_order_2=6)): -38.7396821390842,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=2, on_order_2=7)): -39.654640919609726,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=3, on_order_2=0)): -33.100877688494435,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=3, on_order_2=1)): -36.196187918657024,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=3, on_order_2=2)): -37.03397631263296,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=3, on_order_2=3)): -38.22600411650623,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=3, on_order_2=4)): -38.8306375184452,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=3, on_order_2=5)): -39.7396821390842,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=3, on_order_2=6)): -40.65464091960972,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=4, on_order_2=0)): -32.25013335807542,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=4, on_order_2=1)): -38.03397631263296,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=4, on_order_2=2)): -39.22600411650624,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=4, on_order_2=3)): -39.8306375184452,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=4, on_order_2=4)): -40.73968213908421,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=4, on_order_2=5)): -41.65464091960973,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=5, on_order_2=0)): -30.30712658491546,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=5, on_order_2=1)): -39.999989804908274,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=5, on_order_2=2)): -40.8306375184452,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=5, on_order_2=3)): -41.7396821390842,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=5, on_order_2=4)): -42.654640919609726,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=6, on_order_2=0)): -28.925370489174835,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=6, on_order_2=1)): -40.99999998688431,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=6, on_order_2=2)): -42.7396821390842,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=6, on_order_2=3)): -43.65464091960972,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=7, on_order_2=0)): -28.389807961416746,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=7, on_order_2=1)): -42.000000002160405,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=7, on_order_2=2)): -44.654640919609726,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=8, on_order_2=0)): -43.00000000216041,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=8, on_order_2=1)): -45.65464091960973,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=0, on_hand_2=9, on_order_2=0)): -46.654640919609726,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=0, on_order_2=0)): -32.39760792704286,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=0, on_order_2=1)): -24.491826462302996,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=0, on_order_2=2)): -22.661819675107743,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=0, on_order_2=3)): -23.193386386709147,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=0, on_order_2=4)): -22.52685299337164,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=0, on_order_2=5)): -24.09602380221053,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=0, on_order_2=6)): -25.252967235638767,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=0, on_order_2=7)): -25.967565443107933,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=0, on_order_2=8)): -26.83226465386649,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=0, on_order_2=9)): -27.704650424391634,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=1, on_order_2=0)): -25.180220630274924,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=1, on_order_2=1)): -23.661819675107736,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=1, on_order_2=2)): -24.193386386709147,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=1, on_order_2=3)): -23.52685299337164,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=1, on_order_2=4)): -25.096023802210535,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=1, on_order_2=5)): -26.25296723563877,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=1, on_order_2=6)): -26.967565443107933,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=1, on_order_2=7)): -27.83226465386649,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=1, on_order_2=8)): -28.704650424391637,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=2, on_order_2=0)): -24.24754817776209,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=2, on_order_2=1)): -25.193386386709143,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=2, on_order_2=2)): -24.526852993371644,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=2, on_order_2=3)): -26.09602380221054,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=2, on_order_2=4)): -27.252967235638774,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=2, on_order_2=5)): -27.967565443107933,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=2, on_order_2=6)): -28.832264653866503,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=2, on_order_2=7)): -29.70465042439164,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=3, on_order_2=0)): -26.039132862746392,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=3, on_order_2=1)): -25.526852993371648,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=3, on_order_2=2)): -27.096023802210535,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=3, on_order_2=3)): -28.252967235638767,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=3, on_order_2=4)): -28.967565443107937,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=3, on_order_2=5)): -29.832264653866503,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=3, on_order_2=6)): -30.704650424391637,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=4, on_order_2=0)): -25.878254486207215,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=4, on_order_2=1)): -28.096023802210535,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=4, on_order_2=2)): -29.252967235638767,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=4, on_order_2=3)): -29.967565443107933,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=4, on_order_2=4)): -30.83226465386649,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=4, on_order_2=5)): -31.704650424391637,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=5, on_order_2=0)): -24.99807788602519,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=5, on_order_2=1)): -30.252967235638767,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=5, on_order_2=2)): -30.96756544310793,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=5, on_order_2=3)): -31.83226465386649,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=5, on_order_2=4)): -32.70465042439163,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=6, on_order_2=0)): -24.198349980448526,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=6, on_order_2=1)): -31.96756544310793,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=6, on_order_2=2)): -32.832264653866496,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=6, on_order_2=3)): -33.70465042439163,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=7, on_order_2=0)): -32.96756544310794,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=7, on_order_2=1)): -33.832264653866496,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=7, on_order_2=2)): -34.70465042439163,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=8, on_order_2=0)): -34.832264653866496,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=8, on_order_2=1)): -35.70465042439163,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=1, on_hand_2=9, on_order_2=0)): -36.70465042439163,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=0, on_order_2=0)): -23.631642418390655,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=0, on_order_2=1)): -15.696797500070947,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=0, on_order_2=2)): -13.790657957746129,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=0, on_order_2=3)): -14.190223867941283,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=0, on_order_2=4)): -14.681623535096973,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=0, on_order_2=5)): -13.904420550535049,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=0, on_order_2=6)): -15.623995885817594,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=0, on_order_2=7)): -16.462368766180823,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=0, on_order_2=8)): -17.18228026160459,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=0, on_order_2=9)): -18.019126717971957,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=1, on_order_2=0)): -16.696797500070947,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=1, on_order_2=1)): -14.790657957746129,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=1, on_order_2=2)): -15.190223867941281,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=1, on_order_2=3)): -15.681623535096973,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=1, on_order_2=4)): -14.90442055053505,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=1, on_order_2=5)): -16.6239958858176,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=1, on_order_2=6)): -17.462368766180823,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=1, on_order_2=7)): -18.182280261604593,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=1, on_order_2=8)): -19.019126717971957,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=2, on_order_2=0)): -15.790657957746127,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=2, on_order_2=1)): -16.19022386794128,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=2, on_order_2=2)): -16.681623535096975,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=2, on_order_2=3)): -15.904420550535049,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=2, on_order_2=4)): -17.623995885817596,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=2, on_order_2=5)): -18.462368766180827,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=2, on_order_2=6)): -19.182280261604593,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=2, on_order_2=7)): -20.019126717971957,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=3, on_order_2=0)): -17.19022386794128,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=3, on_order_2=1)): -17.681623535096975,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=3, on_order_2=2)): -16.90442055053505,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=3, on_order_2=3)): -18.623995885817596,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=3, on_order_2=4)): -19.462368766180823,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=3, on_order_2=5)): -20.182280261604593,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=3, on_order_2=6)): -21.019126717971957,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=4, on_order_2=0)): -18.681623535096975,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=4, on_order_2=1)): -17.90442055053505,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=4, on_order_2=2)): -19.6239958858176,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=4, on_order_2=3)): -20.462368766180827,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=4, on_order_2=4)): -21.182280261604596,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=4, on_order_2=5)): -22.019126717971957,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=5, on_order_2=0)): -18.90442055053505,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=5, on_order_2=1)): -20.623995885817592,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=5, on_order_2=2)): -21.462368766180827,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=5, on_order_2=3)): -22.18228026160459,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=5, on_order_2=4)): -23.019126717971957,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=6, on_order_2=0)): -21.623995885817592,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=6, on_order_2=1)): -22.462368766180827,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=6, on_order_2=2)): -23.18228026160459,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=6, on_order_2=3)): -24.019126717971957,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=7, on_order_2=0)): -23.462368766180827,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=7, on_order_2=1)): -24.18228026160459,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=7, on_order_2=2)): -25.01912671797196,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=8, on_order_2=0)): -25.18228026160459,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=8, on_order_2=1)): -26.019126717971954,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=2, on_hand_2=9, on_order_2=0)): -27.019126717971957,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=0, on_order_2=0)): -17.614787220252307,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=0, on_order_2=1)): -9.626382833581225,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=0, on_order_2=2)): -7.57859921306821,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=0, on_order_2=3)): -7.816751758822925,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=0, on_order_2=4)): -8.075995266989551,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=0, on_order_2=5)): -8.001420535270716,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=0, on_order_2=6)): -7.928657503831479,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=0, on_order_2=7)): -9.167214309312822,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=0, on_order_2=8)): -9.884178434184776,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=0, on_order_2=9)): -10.68022465279575,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=1, on_order_2=0)): -10.626382833581225,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=1, on_order_2=1)): -8.578599213068209,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=1, on_order_2=2)): -8.816751758822925,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=1, on_order_2=3)): -9.075995266989553,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=1, on_order_2=4)): -9.001420535270716,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=1, on_order_2=5)): -8.92865750383148,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=1, on_order_2=6)): -10.167214309312822,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=1, on_order_2=7)): -10.884178434184776,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=1, on_order_2=8)): -11.68022465279575,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=2, on_order_2=0)): -9.578599213068209,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=2, on_order_2=1)): -9.816751758822925,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=2, on_order_2=2)): -10.075995266989551,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=2, on_order_2=3)): -10.001420535270714,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=2, on_order_2=4)): -9.928657503831479,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=2, on_order_2=5)): -11.16721430931282,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=2, on_order_2=6)): -11.884178434184777,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=2, on_order_2=7)): -12.680224652795749,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=3, on_order_2=0)): -10.816751758822925,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=3, on_order_2=1)): -11.07599526698955,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=3, on_order_2=2)): -11.001420535270714,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=3, on_order_2=3)): -10.928657503831477,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=3, on_order_2=4)): -12.167214309312818,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=3, on_order_2=5)): -12.884178434184776,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=3, on_order_2=6)): -13.680224652795749,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=4, on_order_2=0)): -12.075995266989553,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=4, on_order_2=1)): -12.001420535270714,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=4, on_order_2=2)): -11.928657503831479,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=4, on_order_2=3)): -13.167214309312822,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=4, on_order_2=4)): -13.884178434184776,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=4, on_order_2=5)): -14.68022465279575,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=5, on_order_2=0)): -13.001420535270713,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=5, on_order_2=1)): -12.928657503831474,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=5, on_order_2=2)): -14.167214309312818,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=5, on_order_2=3)): -14.884178434184774,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=5, on_order_2=4)): -15.680224652795747,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=6, on_order_2=0)): -13.928657503831477,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=6, on_order_2=1)): -15.167214309312818,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=6, on_order_2=2)): -15.884178434184774,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=6, on_order_2=3)): -16.68022465279575,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=7, on_order_2=0)): -16.16721430931282,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=7, on_order_2=1)): -16.884178434184776,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=7, on_order_2=2)): -17.68022465279575,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=8, on_order_2=0)): -17.88417843418478,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=8, on_order_2=1)): -18.680224652795747,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=3, on_hand_2=9, on_order_2=0)): -19.68022465279575,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=0, on_order_2=0)): -14.858340212284858,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=0, on_order_2=1)): -6.831029454029942,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=0, on_order_2=2)): -4.649707438476295,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=0, on_order_2=3)): -4.713823075223843,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=0, on_order_2=4)): -4.792455391389828,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=0, on_order_2=5)): -4.898472921083696,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=0, on_order_2=6)): -5.113474896415783,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=0, on_order_2=7)): -4.831628362951519,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=0, on_order_2=8)): -5.982936032171682,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=0, on_order_2=9)): -6.528195531248697,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=1, on_order_2=0)): -7.831029454029942,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=1, on_order_2=1)): -5.6497074384762955,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=1, on_order_2=2)): -5.713823075223843,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=1, on_order_2=3)): -5.792455391389828,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=1, on_order_2=4)): -5.898472921083696,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=1, on_order_2=5)): -6.113474896415783,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=1, on_order_2=6)): -5.831628362951519,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=1, on_order_2=7)): -6.982936032171682,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=1, on_order_2=8)): -7.528195531248697,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=2, on_order_2=0)): -6.649707438476295,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=2, on_order_2=1)): -6.713823075223843,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=2, on_order_2=2)): -6.792455391389828,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=2, on_order_2=3)): -6.898472921083696,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=2, on_order_2=4)): -7.113474896415782,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=2, on_order_2=5)): -6.83162836295152,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=2, on_order_2=6)): -7.982936032171681,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=2, on_order_2=7)): -8.528195531248697,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=3, on_order_2=0)): -7.289768538037567,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=3, on_order_2=1)): -5.900422220774359,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=3, on_order_2=2)): -7.898472921083696,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=3, on_order_2=3)): -8.113474896415783,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=3, on_order_2=4)): -7.831628362951518,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=3, on_order_2=5)): -8.982936032171683,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=3, on_order_2=6)): -9.528195531248699,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=4, on_order_2=0)): -6.900422220774359,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=4, on_order_2=1)): -8.898472921083696,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=4, on_order_2=2)): -9.11347489641578,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=4, on_order_2=3)): -8.831628362951522,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=4, on_order_2=4)): -9.982936032171683,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=4, on_order_2=5)): -10.528195531248699,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=5, on_order_2=0)): -9.898472921083696,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=5, on_order_2=1)): -10.113474896415783,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=5, on_order_2=2)): -9.83162836295152,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=5, on_order_2=3)): -10.982936032171683,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=5, on_order_2=4)): -11.528195531248699,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=6, on_order_2=0)): -11.113474896415783,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=6, on_order_2=1)): -10.831628362951518,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=6, on_order_2=2)): -11.98293603217168,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=6, on_order_2=3)): -12.528195531248695,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=7, on_order_2=0)): -11.831628362951516,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=7, on_order_2=1)): -12.982936032171683,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=7, on_order_2=2)): -13.528195531248699,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=8, on_order_2=0)): -13.98293603217168,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=8, on_order_2=1)): -14.528195531248695,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=4, on_hand_2=9, on_order_2=0)): -15.528195531248693,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=0)): -13.791570293120909,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=1)): -5.726973744972945,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=2)): -3.479492561620666,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=3)): -3.4288943027369294,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=4)): -3.331219533710188,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=5)): -3.3013783615740797,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=6)): -3.4310127555447645,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=7)): -3.687303287138158,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=8)): -3.2617648797168743,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=9)): -4.287223291150871,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=0)): -6.726973744972945,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=1)): -4.479492561620667,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=2)): -4.428894302736929,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=3)): -4.331219533710188,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=4)): -4.30137836157408,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=5)): -4.4310127555447645,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=6)): -4.687303287138159,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=7)): -4.261764879716875,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=8)): -5.287223291150871,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=0)): -5.479492561620666,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=1)): -5.4288943027369285,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=2)): -5.331219533710188,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=3)): -5.30137836157408,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=4)): -5.431012755544764,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=5)): -5.687303287138159,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=6)): -5.261764879716875,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=7)): -6.287223291150871,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=0)): -6.4288943027369285,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=1)): -6.331219533710188,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=2)): -6.301378361574081,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=3)): -6.431012755544765,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=4)): -6.687303287138159,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=5)): -6.261764879716875,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=6)): -7.287223291150871,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=4, on_order_2=0)): -7.331219533710188,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=4, on_order_2=1)): -7.301378361574081,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=4, on_order_2=2)): -7.431012755544765,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=4, on_order_2=3)): -7.68730328713816,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=4, on_order_2=4)): -7.261764879716875,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=4, on_order_2=5)): -8.287223291150873,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=5, on_order_2=0)): -8.30137836157408,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=5, on_order_2=1)): -8.431012755544764,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=5, on_order_2=2)): -8.687303287138157,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=5, on_order_2=3)): -8.261764879716875,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=5, on_order_2=4)): -9.287223291150871,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=6, on_order_2=0)): -9.431012755544767,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=6, on_order_2=1)): -9.68730328713816,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=6, on_order_2=2)): -9.261764879716875,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=6, on_order_2=3)): -10.287223291150873,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=7, on_order_2=0)): -10.687303287138157,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=7, on_order_2=1)): -10.261764879716875,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=7, on_order_2=2)): -11.287223291150873,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=8, on_order_2=0)): -11.261764879716871,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=8, on_order_2=1)): -12.287223291150871,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=9, on_order_2=0)): -13.287223291150873,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=0)): -13.14232188610611,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=1)): -5.0118163995977945,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=2)): -2.635953612943031,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=3)): -2.4642847171405284,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=4)): -2.234763982449805,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=5)): -2.037629837907356,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=6)): -1.9530899274800357,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=7)): -2.057469243296938,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=8)): -2.286802372923831,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=9)): -2.035604808219148,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=0)): -6.011816399597794,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=1)): -3.635953612943031,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=2)): -3.4642847171405284,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=3)): -3.234763982449805,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=4)): -3.037629837907356,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=5)): -2.9530899274800357,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=6)): -3.0574692432969375,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=7)): -3.286802372923831,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=8)): -3.035604808219148,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=0)): -4.635953612943031,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=1)): -4.464284717140529,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=2)): -4.234763982449806,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=3)): -4.037629837907357,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=4)): -3.953089927480036,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=5)): -4.0574692432969375,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=6)): -4.286802372923832,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=7)): -4.035604808219149,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=0)): -5.464284717140529,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=1)): -5.234763982449806,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=2)): -5.037629837907358,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=3)): -4.953089927480038,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=4)): -5.057469243296939,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=5)): -5.286802372923834,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=6)): -5.035604808219149,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=4, on_order_2=0)): -6.234763982449806,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=4, on_order_2=1)): -6.037629837907357,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=4, on_order_2=2)): -5.953089927480035,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=4, on_order_2=3)): -6.057469243296939,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=4, on_order_2=4)): -6.28680237292383,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=4, on_order_2=5)): -6.035604808219148,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=5, on_order_2=0)): -7.037629837907357,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=5, on_order_2=1)): -6.953089927480035,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=5, on_order_2=2)): -7.0574692432969375,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=5, on_order_2=3)): -7.286802372923832,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=5, on_order_2=4)): -7.035604808219149,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=6, on_order_2=0)): -7.95308992748004,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=6, on_order_2=1)): -8.05746924329694,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=6, on_order_2=2)): -8.286802372923834,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=6, on_order_2=3)): -8.03560480821915,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=7, on_order_2=0)): -9.05746924329694,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=7, on_order_2=1)): -9.286802372923834,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=7, on_order_2=2)): -9.03560480821915,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=8, on_order_2=0)): -10.286802372923827,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=8, on_order_2=1)): -10.035604808219148,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=9, on_order_2=0)): -11.035604808219144,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=0)): -12.524396542606281,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=1)): -4.360527712804579,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=2)): -1.8992544533290154,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=3)): -1.62795793012494,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=4)): -1.2772949278580747,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=5)): -1.0474809645353185,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=6)): -0.9534573356335452,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=7)): -0.9074779365981779,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=8)): -0.9799008103133036,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=9)): -1.139365785661316,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=0)): -5.360527712804578,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=1)): -2.899254453329015,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=2)): -2.62795793012494,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=3)): -2.2772949278580747,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=4)): -2.0474809645353185,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=5)): -1.9534573356335456,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=6)): -1.9074779365981775,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=7)): -1.9799008103133038,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=8)): -2.139365785661316,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=0)): -3.899254453329015,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=1)): -3.6279579301249396,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=2)): -3.277294927858075,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=3)): -3.0474809645353185,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=4)): -2.9534573356335447,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=5)): -2.9074779365981773,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=6)): -2.9799008103133042,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=7)): -3.139365785661317,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=0)): -4.627957930124939,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=1)): -4.277294927858074,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=2)): -4.0474809645353185,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=3)): -3.953457335633545,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=4)): -3.9074779365981764,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=5)): -3.979900810313303,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=6)): -4.139365785661316,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=4, on_order_2=0)): -5.277294927858075,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=4, on_order_2=1)): -5.04748096453532,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=4, on_order_2=2)): -4.953457335633545,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=4, on_order_2=3)): -4.907477936598179,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=4, on_order_2=4)): -4.979900810313304,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=4, on_order_2=5)): -5.139365785661317,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=5, on_order_2=0)): -6.047480964535318,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=5, on_order_2=1)): -5.953457335633542,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=5, on_order_2=2)): -5.907477936598175,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=5, on_order_2=3)): -5.9799008103133025,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=5, on_order_2=4)): -6.139365785661317,
#   NonTerminal(state=InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=6, on_order_2=0)): -6.953457335633547,
# ...
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=7): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=8): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=0, on_order_2=9): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=0): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=1): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=2): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=3): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=4): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=5): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=6): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=7): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=1, on_order_2=8): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=0): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=1): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=2): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=3): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=4): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=5): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=6): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=2, on_order_2=7): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=0): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=1): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=2): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=3): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=4): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=5): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=3, on_order_2=6): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=4, on_order_2=0): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=4, on_order_2=1): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=4, on_order_2=2): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=4, on_order_2=3): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=4, on_order_2=4): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=4, on_order_2=5): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=5, on_order_2=0): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=5, on_order_2=1): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=5, on_order_2=2): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=5, on_order_2=3): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=5, on_order_2=4): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=6, on_order_2=0): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=6, on_order_2=1): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=6, on_order_2=2): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=6, on_order_2=3): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=7, on_order_2=0): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=7, on_order_2=1): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=7, on_order_2=2): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=8, on_order_2=0): Do Action (2, 2, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=8, on_order_2=1): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=5, on_hand_2=9, on_order_2=0): Do Action (2, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=0): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=1): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=2): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=3): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=4): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=5): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=6): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=7): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=8): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=0, on_order_2=9): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=0): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=1): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=2): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=3): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=4): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=5): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=6): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=7): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=1, on_order_2=8): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=0): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=1): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=2): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=3): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=4): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=5): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=6): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=2, on_order_2=7): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=0): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=1): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=2): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=3): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=4): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=5): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=3, on_order_2=6): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=4, on_order_2=0): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=4, on_order_2=1): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=4, on_order_2=2): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=4, on_order_2=3): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=4, on_order_2=4): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=4, on_order_2=5): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=5, on_order_2=0): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=5, on_order_2=1): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=5, on_order_2=2): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=5, on_order_2=3): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=5, on_order_2=4): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=6, on_order_2=0): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=6, on_order_2=1): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=6, on_order_2=2): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=6, on_order_2=3): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=7, on_order_2=0): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=7, on_order_2=1): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=7, on_order_2=2): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=8, on_order_2=0): Do Action (1, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=8, on_order_2=1): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=6, on_hand_2=9, on_order_2=0): Do Action (1, 1, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=0): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=1): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=2): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=3): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=4): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=5): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=6): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=7): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=8): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=0, on_order_2=9): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=0): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=1): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=2): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=3): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=4): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=5): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=6): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=7): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=1, on_order_2=8): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=0): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=1): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=2): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=3): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=4): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=5): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=6): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=2, on_order_2=7): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=0): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=1): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=2): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=3): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=4): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=5): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=3, on_order_2=6): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=4, on_order_2=0): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=4, on_order_2=1): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=4, on_order_2=2): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=4, on_order_2=3): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=4, on_order_2=4): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=4, on_order_2=5): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=5, on_order_2=0): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=5, on_order_2=1): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=5, on_order_2=2): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=5, on_order_2=3): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=5, on_order_2=4): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=6, on_order_2=0): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=6, on_order_2=1): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=6, on_order_2=2): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=6, on_order_2=3): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=7, on_order_2=0): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=7, on_order_2=1): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=7, on_order_2=2): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=8, on_order_2=0): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=8, on_order_2=1): Do Action (0, 0, 0)
#  For State InventoryState(on_hand_1=0, on_order_1=7, on_hand_2=9, on_order_2=0): Do Action (0, 0, 0))
